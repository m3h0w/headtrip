# %%
# @title ⬅️ **Split Video In Frames**
# !mkdir input output
# !ffmpeg -i ./input.mp4 -f image2 ./input/image-%04d.png
# Out:
# ffmpeg version 6.0 Copyright (c) 2000-2023 the FFmpeg developers
#   built with Apple clang version 15.0.0 (clang-1500.0.40.1)
# ...

# %%
yaml_conf_string = """
######### Hyperparameters
num_iterations: 10
num_octaves: 12
octave_scale: 1.2
lr: 0.008
# Random Hyperparameter
random: False
#########
# Guided Dreaming on/off
guided: True
# takes the max classd 
max_output: False
# takes the max class on each octave
pyramid_max: True
# takes all the classes from the list
channel_list: [863]
# if you want to dream on other layers
no_class: False
at_layer: 26
##########
# optical flow spynet or opencv farneback
use_spynet: False
###########
use_depth: False
depth_str: 1.2
# use Threshold on mask to set specific areas to 0
use_threshold: True
th_val: 0.2
invert_depth: False #foreground/background
#########
pretrained: True
########
# input and output path
input: "input/"
outpath: "output"
# sequence startposition when sorted
start_position: 0
######
#c hange model here, available are 
# resnet, vgg, alexnet, inception, densenet, mobile, resnetx, squeeze, masnet, googlenet
model: vgg19
######
detail_blending_coef: 0

# set true for video sequence
seq: True

# float precision 16
fp16: False
"""

# save config
with open("configs/custom_conf.yaml", "w") as f:
    f.write(yaml_conf_string)

# !rm -r output
# @title ⬅️ **Dream Every Frame**
# !python dream.py --config ./configs/custom_conf.yaml
# Out:
# /Users/mehow/src-uni/Pytorch-HeadTrip/venv/lib/python3.11/site-packages/torchvision/models/_utils.py:208: UserWarning: The parameter 'pretrained' is deprecated since 0.13 and may be removed in the future, please use 'weights' instead.
#   warnings.warn(
# /Users/mehow/src-uni/Pytorch-HeadTrip/venv/lib/python3.11/site-packages/torchvision/models/_utils.py:223: UserWarning: Arguments other than a weight enum or `None` for 'weights' are deprecated since 0.13 and may be removed in the future. The current behavior is equivalent to passing `weights=VGG19_Weights.IMAGENET1K_V1`. You can also use `weights=VGG19_Weights.DEFAULT` to get the most up-to-date weights.
#   warnings.warn(msg)
# Using cache found in depth_model/intel-isl_MiDaS_master
# Loading weights:  None
# Using cache found in depth_model/rwightman_gen-efficientnet-pytorch_master
# Using cache found in depth_model/intel-isl_MiDaS_master
# 5 1.2 12 0.008
# ...

# %%
# @title ⬅️ **Combine The Deep Dreamed Images Back And Download**

# mp4 and force overwrite
# !ffmpeg -i ./output/image-%04d.png -r 30 -pix_fmt yuv420p -vf "scale=trunc(iw/2)*2:trunc(ih/2)*2" ./dreamvideo.mp4 -y

# from google.colab import files

# files.download("dreamvideo.avi")
# Out:
# ffmpeg version 6.0 Copyright (c) 2000-2023 the FFmpeg developers
#   built with Apple clang version 15.0.0 (clang-1500.0.40.1)
# ...
